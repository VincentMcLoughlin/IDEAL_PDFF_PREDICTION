# %%
import pandas as pd 
from glob import glob

#ideal_df = pd.read_csv("/home/mclougv/IDEAL_PDFF_prediction/reference_data/IDEAL_x20254_2_with_Path.csv")
ideal_df = pd.read_csv("/home/mclougv/IDEAL_PDFF_prediction/reference_data/IDEAL_X20254_2.csv")

print(ideal_df.shape)
print(ideal_df.head())
# Out:
# (42881, 8)
#    Unnamed: 0  X               filename      eid  subfolder  X40060_2_0  \
# 0           1  1  1000015_20254_2_0.zip  1000015          1         1.2
# 1           2  2  1000088_20254_2_0.zip  1000088          1         NaN
# 2           3  3  1000154_20254_2_0.zip  1000154          1         1.1
# 3           4  4  1000618_20254_2_0.zip  1000618          1         1.7
# 4           5  5  1000795_20254_2_0.zip  1000795          1         1.2
#
#    X40061_2_0  X40062_2_0
# 0         3.0       655.0
# 1         NaN         NaN
# 2         8.9       752.0
# 3        10.3       756.0
# 4         2.0       790.0

# %%
file_list = glob("/genetics3/mclougv/LIVER_MRI/raw_data_field_20254/field_20254_2/*/*")
print(len(file_list))
# Out:
# 42881

# %%
import pandas as pd
ideal_path_df = pd.read_csv("reference_data/IDEAL_x20254_2_with_Path.csv")
ideal_path_df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  X               filename      eid  subfolder  \
# 0             0           1  1  1000015_20254_2_0.zip  1000015          1
# 1             1           2  2  1000088_20254_2_0.zip  1000088          1
# 2             2           3  3  1000154_20254_2_0.zip  1000154          1
# 3             3           4  4  1000618_20254_2_0.zip  1000618          1
# 4             4           5  5  1000795_20254_2_0.zip  1000795          1
#
#    liver_iron  PDFF    cT1                                          full_path  \
# 0         1.2   3.0  655.0  /genetics3/mclougv/LIVER_MRI/raw_data_field_20...
# 1         NaN   NaN    NaN  /genetics3/mclougv/LIVER_MRI/raw_data_field_20...
# 2         1.1   8.9  752.0  /genetics3/mclougv/LIVER_MRI/raw_data_field_20...
# 3         1.7  10.3  756.0  /genetics3/mclougv/LIVER_MRI/raw_data_field_20...
# 4         1.2   2.0  790.0  /genetics3/mclougv/LIVER_MRI/raw_data_field_20...
#
#       filename_from_path
# 0  1000015_20254_2_0.zip
# 1  1000088_20254_2_0.zip
# 2  1000154_20254_2_0.zip
# 3  1000618_20254_2_0.zip
# 4  1000795_20254_2_0.zip

# %%
ideal_path_df["eid_from_path"] = pd.to_numeric(ideal_path_df["filename_from_path"].str[:7])
ideal_path_df["eid_from_filename"] = pd.to_numeric(ideal_path_df["filename"].str[:7])
ideal_path_df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  X               filename      eid  subfolder  \
# 0             0           1  1  1000015_20254_2_0.zip  1000015          1
# 1             1           2  2  1000088_20254_2_0.zip  1000088          1
# 2             2           3  3  1000154_20254_2_0.zip  1000154          1
# 3             3           4  4  1000618_20254_2_0.zip  1000618          1
# 4             4           5  5  1000795_20254_2_0.zip  1000795          1
#
#    liver_iron  PDFF    cT1                                          full_path  \
# 0         1.2   3.0  655.0  /genetics3/mclougv/LIVER_MRI/raw_data_field_20...
# 1         NaN   NaN    NaN  /genetics3/mclougv/LIVER_MRI/raw_data_field_20...
# 2         1.1   8.9  752.0  /genetics3/mclougv/LIVER_MRI/raw_data_field_20...
# 3         1.7  10.3  756.0  /genetics3/mclougv/LIVER_MRI/raw_data_field_20...
# 4         1.2   2.0  790.0  /genetics3/mclougv/LIVER_MRI/raw_data_field_20...
#
#       filename_from_path  eid_from_path  eid_from_filename
# 0  1000015_20254_2_0.zip        1000015            1000015
# 1  1000088_20254_2_0.zip        1000088            1000088
# 2  1000154_20254_2_0.zip        1000154            1000154
# 3  1000618_20254_2_0.zip        1000618            1000618
# 4  1000795_20254_2_0.zip        1000795            1000795

# %%
ideal_path_df[ideal_path_df["eid_from_filename"] != ideal_path_df["eid_from_path"]]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0.1, Unnamed: 0, X, filename, eid, subfolder, liver_iron, PDFF, cT1, full_path, filename_from_path, eid_from_path, eid_from_filename]
# Index: []

# %%
ideal_path_clean_df = ideal_path_df[ideal_path_df["PDFF"].notna()]
print(ideal_path_clean_df.shape)
# Out:
# (33252, 13)

# %%
ideal_path_clean_df.to_csv("reference_data/IDEAL_x20254_2_with_Path_No_PDFF_Na.csv")

# %%
#Count number of zip files

import sys
from contextlib import closing
from zipfile import ZipFile

def get_file_count_from_zip(zip_path):
    with closing(ZipFile(zip_path)) as archive:
        return len(archive.infolist())
    
expected_file_num = 73 #expect 72 dicom, (36 light, 36 dark), plus a txt file
print(ideal_path_clean_df.shape)
ideal_path_clean_df["num_files"] = ideal_path_clean_df["full_path"].map(get_file_count_from_zip) #25 minutes to run
ideal_path_clean_df.head()
# Out:
# (33252, 13)
# /tmp/ipykernel_6519/3870582693.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ideal_path_clean_df["num_files"] = ideal_path_clean_df["full_path"].map(get_file_count_from_zip)
#    Unnamed: 0.1  Unnamed: 0  X               filename      eid  subfolder  \
# 0             0           1  1  1000015_20254_2_0.zip  1000015          1
# 2             2           3  3  1000154_20254_2_0.zip  1000154          1
# 3             3           4  4  1000618_20254_2_0.zip  1000618          1
# 4             4           5  5  1000795_20254_2_0.zip  1000795          1
# 6             6           7  7  1001138_20254_2_0.zip  1001138          1
#
#    liver_iron  PDFF    cT1                                          full_path  \
# 0         1.2   3.0  655.0  /genetics3/mclougv/LIVER_MRI/raw_data_field_20...
# 2         1.1   8.9  752.0  /genetics3/mclougv/LIVER_MRI/raw_data_field_20...
# 3         1.7  10.3  756.0  /genetics3/mclougv/LIVER_MRI/raw_data_field_20...
# 4         1.2   2.0  790.0  /genetics3/mclougv/LIVER_MRI/raw_data_field_20...
# 6         1.1   2.1  670.0  /genetics3/mclougv/LIVER_MRI/raw_data_field_20...
#
#       filename_from_path  eid_from_path  eid_from_filename  num_files
# 0  1000015_20254_2_0.zip        1000015            1000015         73
# 2  1000154_20254_2_0.zip        1000154            1000154         73
# 3  1000618_20254_2_0.zip        1000618            1000618         73
# 4  1000795_20254_2_0.zip        1000795            1000795         73
# 6  1001138_20254_2_0.zip        1001138            1001138         73

# %%
ideal_good_files_df =ideal_path_clean_df[ideal_path_clean_df["num_files"] == expected_file_num]
print(ideal_path_clean_df.shape)
print(ideal_good_files_df.shape)
# Out:
# (33252, 14)
# (33242, 14)

# %%
ideal_good_files_df.drop(columns=["Unnamed: 0.1", "Unnamed: 0", "X"], inplace=True)
print(ideal_good_files_df.shape)
ideal_good_files_df

# %%
ideal_good_files_df.to_csv("reference_data/IDEAL_x20254_2_clean_with_path.csv")

# %%
ideal_good_files_df[ideal_good_files_df["filename_from_path"] == "4491437_20254_2_0.zip"]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0.1, Unnamed: 0, X, filename, eid, subfolder, liver_iron, PDFF, cT1, full_path, filename_from_path, eid_from_path, eid_from_filename, num_files]
# Index: []

# %%
# Out:
# (33242, 11)
# /tmp/ipykernel_6519/4219057579.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ideal_good_files_df.drop(columns=["Unnamed: 0.1", "Unnamed: 0", "X"], inplace=True)
#                     filename      eid  subfolder  liver_iron  PDFF    cT1  \
# 0      1000015_20254_2_0.zip  1000015          1         1.2   3.0  655.0
# 2      1000154_20254_2_0.zip  1000154          1         1.1   8.9  752.0
# 3      1000618_20254_2_0.zip  1000618          1         1.7  10.3  756.0
# 4      1000795_20254_2_0.zip  1000795          1         1.2   2.0  790.0
# 6      1001138_20254_2_0.zip  1001138          1         1.1   2.1  670.0
# ...                      ...      ...        ...         ...   ...    ...
# 42873  6025157_20254_2_0.zip  6025157         43         1.0   2.5  737.0
# 42876  6025418_20254_2_0.zip  6025418         43         1.2   5.0  786.0
# 42877  6025780_20254_2_0.zip  6025780         43         1.1   6.0  670.0
# 42878  6025943_20254_2_0.zip  6025943         43         1.0   2.0  703.0
# 42879  6026224_20254_2_0.zip  6026224         43         1.3   2.6  641.0
#
#                                                full_path  \
# 0      /genetics3/mclougv/LIVER_MRI/raw_data_field_20...
# 2      /genetics3/mclougv/LIVER_MRI/raw_data_field_20...
# 3      /genetics3/mclougv/LIVER_MRI/raw_data_field_20...
# 4      /genetics3/mclougv/LIVER_MRI/raw_data_field_20...
# 6      /genetics3/mclougv/LIVER_MRI/raw_data_field_20...
# ...                                                  ...
# 42873  /genetics3/mclougv/LIVER_MRI/raw_data_field_20...
# 42876  /genetics3/mclougv/LIVER_MRI/raw_data_field_20...
# 42877  /genetics3/mclougv/LIVER_MRI/raw_data_field_20...
# 42878  /genetics3/mclougv/LIVER_MRI/raw_data_field_20...
# 42879  /genetics3/mclougv/LIVER_MRI/raw_data_field_20...
#
#           filename_from_path  eid_from_path  eid_from_filename  num_files
# 0      1000015_20254_2_0.zip        1000015            1000015         73
# 2      1000154_20254_2_0.zip        1000154            1000154         73
# 3      1000618_20254_2_0.zip        1000618            1000618         73
# 4      1000795_20254_2_0.zip        1000795            1000795         73
# 6      1001138_20254_2_0.zip        1001138            1001138         73
# ...                      ...            ...                ...        ...
# 42873  6025157_20254_2_0.zip        6025157            6025157         73
# 42876  6025418_20254_2_0.zip        6025418            6025418         73
# 42877  6025780_20254_2_0.zip        6025780            6025780         73
# 42878  6025943_20254_2_0.zip        6025943            6025943         73
# 42879  6026224_20254_2_0.zip        6026224            6026224         73
#
# [33242 rows x 11 columns]
